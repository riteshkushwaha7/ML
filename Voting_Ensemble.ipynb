# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshkushwaha7/ML/blob/main/Voting_Ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

print(X.shape)
print(y.shape)
print(iris.target_names)
# Out:
# (150, 4)
# (150,)
# ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

lr = LogisticRegression(random_state=1)
svm = SVC(kernel='rbf', probability=True, random_state=1)
rf = RandomForestClassifier(n_estimators=10, random_state=1)

voting_clf = VotingClassifier(estimators=[('lr', lr), ('svm', svm), ('rf', rf)], voting='soft')
voting_clf.fit(X_train, y_train)

print(voting_clf.score(X_test, y_test))
# Out:
# 0.9555555555555556

# %%
from sklearn.metrics import accuracy_score

y_pred = voting_clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9555555555555556

# %%
y_pred_lr = lr.fit(X_train, y_train).predict(X_test)
y_pred_svm = svm.fit(X_train, y_train).predict(X_test)
y_pred_rf = rf.fit(X_train, y_train).predict(X_test)

print('Accuracy of Logistic Regression: ', accuracy_score(y_test, y_pred_lr))
print('Accuracy of SVM: ', accuracy_score(y_test, y_pred_svm))
print('Accuracy of Random Forest: ', accuracy_score(y_test, y_pred_rf))
print('Accuracy of Voting Classifier: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy of Logistic Regression:  0.9777777777777777
# Accuracy of SVM:  0.9777777777777777
# Accuracy of Random Forest:  0.9555555555555556
# Accuracy of Voting Classifier:  0.9555555555555556
